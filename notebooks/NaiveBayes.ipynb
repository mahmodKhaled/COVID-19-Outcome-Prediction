# %% [markdown]
# # Inlcuding Header Files

# %%
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# # Process Data

# %%
# %run process_data.ipynb import *

# %%
X_train , X_test , yTrain , yTest = process_data()

# %% [markdown]
# # Naive Bayes has no Hyperparameters to tune

# %% [markdown]
# # Naive Bayes model

# %%
classifier = GaussianNB()
classifier.fit(X_train , yTrain)
# Out:
# GaussianNB()

# %% [markdown]
# we will predict the output for the test data

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# # Evaluating the model

# %%
# %run evaluation.ipynb import *

# %%
cm , cr = confusion_mat(yTest, y_pred)
print("Confusion matrix\n\n" ,cm , "\n")
print(cr)
# Out:
# Confusion matrix
#
#  [[17 62]
#  [ 1  7]]
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.22      0.35        79
#            1       0.10      0.88      0.18         8
#
#     accuracy                           0.28        87
#    macro avg       0.52      0.55      0.27        87
# weighted avg       0.87      0.28      0.34        87

# %%
roc_plot(yTest, X_test)

# %%
score = roc_score(yTest, X_test)
print("ROC AUC Score: ", score)
# Out:
# ROC AUC Score:  0.8180379746835444
